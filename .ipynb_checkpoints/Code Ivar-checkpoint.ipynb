# %%
#setting up the working environment, Plotly still not working properly\n",
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os
plt.style.use('ggplot')


conda update conda
conda remove distribute setuptools pip
conda install pip
sudo pip install plotly --upgrade
# Out:
#   File "<ipython-input-11-04241c6cad85>", line 10
#     $ conda update conda
#     ^
# SyntaxError: invalid syntax

# %%
#Loading in all tables
os.chdir("C://Users//ivarnieuwepc//Documents//GitHub//Data")
os.getcwd()

df_sdg = pd.read_csv("SDG//SDGData.csv")
df_wdi = pd.read_csv("WDI//WDIData.csv")
df_emd = pd.read_csv("Other//disaster_data_africa_1960_2018_conv.csv", sep = '\t',encoding = 'latin-1')
df_emd
# Out:
#       year         disaster type  iso                            country_name  \
# 0     1960            Earthquake  DZA                                 Algeria
# 1     1960            Earthquake  MAR                                 Morocco
# 2     1960                 Storm  MUS                               Mauritius
# 3     1961            Earthquake  ETH                                Ethiopia
# 4     1961                 Flood  SOM                                 Somalia
# 5     1962                 Flood  TUN                                 Tunisia
# 6     1963            Earthquake  LBY                                   Libya
# 7     1963                 Flood  DZA                                 Algeria
# 8     1963                 Flood  MAR                                 Morocco
# 9     1964               Drought  SOM                                 Somalia
# 10    1964               Drought  ZAF                            South Africa
# 11    1964            Earthquake  TZA            Tanzania, United Republic of
# 12    1964                 Flood  KEN                                   Kenya
# 13    1964                 Flood  MAR                                 Morocco
# 14    1964                 Flood  TZA            Tanzania, United Republic of
# 15    1964                 Flood  TUN                                 Tunisia
# 16    1965               Drought  BWA                                Botswana
# 17    1965               Drought  ETH                                Ethiopia
# 18    1965               Drought  KEN                                   Kenya
# 19    1965               Drought  MRT                              Mauritania
# 20    1965            Earthquake  DZA                                 Algeria
# 21    1965              Epidemic  SEN                                 Senegal
# 22    1965              Epidemic  SOM                                 Somalia
# 23    1965              Epidemic  SDN                             Sudan (the)
# 24    1965                 Flood  MAR                                 Morocco
# 25    1966               Drought  BFA                            Burkina Faso
# 26    1966               Drought  TCD                                    Chad
# 27    1966               Drought  MLI                                    Mali
# 28    1966               Drought  MAR                                 Morocco
# 29    1966               Drought  NER                             Niger (the)
# ...    ...                   ...  ...                                     ...
# 1964  2017              Wildfire  TUN                                 Tunisia
# 1965  2018              Epidemic  COD  Congo (the Democratic Republic of the)
# 1966  2018              Epidemic  NER                             Niger (the)
# 1967  2018              Epidemic  NGA                                 Nigeria
# 1968  2018              Epidemic  UGA                                  Uganda
# 1969  2018  Extreme temperature   MAR                                 Morocco
# 1970  2018                 Flood  AGO                                  Angola
# 1971  2018                 Flood  BWA                                Botswana
# 1972  2018                 Flood  BDI                                 Burundi
# 1973  2018                 Flood  COD  Congo (the Democratic Republic of the)
# 1974  2018                 Flood  CIV                           Côte dIvoire
# 1975  2018                 Flood  GHA                                   Ghana
# 1976  2018                 Flood  KEN                                   Kenya
# 1977  2018                 Flood  MWI                                  Malawi
# 1978  2018                 Flood  MOZ                              Mozambique
# 1979  2018                 Flood  NER                             Niger (the)
# 1980  2018                 Flood  NGA                                 Nigeria
# 1981  2018                 Flood  RWA                                  Rwanda
# 1982  2018                 Flood  SDN                             Sudan (the)
# 1983  2018                 Flood  TZA            Tanzania, United Republic of
# 1984  2018                 Flood  TUN                                 Tunisia
# 1985  2018             Landslide  ETH                                Ethiopia
# 1986  2018             Landslide  MOZ                              Mozambique
# 1987  2018             Landslide  RWA                                  Rwanda
# 1988  2018                 Storm  DJI                                Djibouti
# 1989  2018                 Storm  GNB                           Guinea-Bissau
# 1990  2018                 Storm  MDG                              Madagascar
# 1991  2018                 Storm  MUS                               Mauritius
# 1992  2018                 Storm  REU                                 Réunion
# 1993  2018                 Storm  SOM                                 Somalia
#
#       occurrence  Total deaths  Injured   Affected  Homeless  Total affected  \
# 0              1          57.0      NaN        NaN    1250.0          1250.0
# 1              1       12000.0  25000.0        NaN       NaN         25000.0
# 2              1          42.0      NaN        NaN       NaN             NaN
# 3              1           NaN      NaN        NaN       NaN             NaN
# 4              1         200.0      NaN        NaN       NaN             NaN
# 5              1          40.0      NaN        NaN       NaN             NaN
# 6              1         320.0      NaN        NaN       NaN             NaN
# 7              1           NaN      NaN    45400.0       NaN         45400.0
# 8              2         169.0     10.0    35000.0       NaN         35010.0
# 9              1          50.0      NaN   700000.0       NaN        700000.0
# 10             1           NaN      NaN     5000.0       NaN          5000.0
# 11             1           4.0      NaN      500.0       NaN           500.0
# 12             1           NaN      NaN    15000.0       NaN         15000.0
# 13             1          76.0      NaN        NaN       NaN             NaN
# 14             1           NaN      NaN    10000.0    3900.0         13900.0
# 15             2          49.0      NaN    21000.0       NaN         21000.0
# 16             1           NaN      NaN    60000.0       NaN         60000.0
# 17             1        2000.0      NaN  1500000.0       NaN       1500000.0
# 18             1           NaN      NaN   260000.0       NaN        260000.0
# 19             1           NaN      NaN    46000.0       NaN         46000.0
# 20             1           2.0    350.0    37000.0   12000.0         49350.0
# 21             1          60.0      NaN      150.0       NaN           150.0
# 22             1           NaN      NaN        NaN       NaN             NaN
# 23             1           NaN      NaN     2300.0       NaN          2300.0
# 24             2          75.0      NaN    47813.0       NaN         47813.0
# 25             1           NaN      NaN        NaN       NaN             NaN
# 26             1           NaN      NaN        NaN       NaN             NaN
# 27             1           NaN      NaN        NaN       NaN             NaN
# 28             1           NaN      NaN        NaN       NaN             NaN
# 29             1           NaN      NaN        NaN       NaN             NaN
# ...          ...           ...      ...        ...       ...             ...
# 1964           1           NaN      NaN     2000.0       NaN          2000.0
# 1965           2         137.0    169.0        NaN       NaN           169.0
# 1966           1          68.0   3692.0        NaN       NaN          3692.0
# 1967           1          90.0   1081.0        NaN       NaN          1081.0
# 1968           1          31.0      NaN     1000.0       NaN          1000.0
# 1969           1           NaN      NaN    70000.0       NaN         70000.0
# 1970           1           8.0      NaN     3000.0       NaN          3000.0
# 1971           1           NaN      NaN     4225.0       NaN          4225.0
# 1972           1           NaN      NaN    12000.0       NaN         12000.0
# 1973           1          51.0     17.0        NaN   15743.0         15760.0
# 1974           1          20.0      NaN    25000.0       NaN         25000.0
# 1975           1          35.0      NaN        NaN       NaN             NaN
# 1976           3         134.0     33.0   211155.0       NaN        211188.0
# 1977           2           1.0      NaN      500.0       NaN           500.0
# 1978           1          11.0      NaN        NaN   77150.0         77150.0
# 1979           1          36.0      NaN   130468.0       NaN        130468.0
# 1980           2         301.0    171.0    15701.0       NaN         15872.0
# 1981           2         134.0      5.0    26360.0       NaN         26365.0
# 1982           2          46.0    121.0   115705.0    8900.0        124726.0
# 1983           1          24.0      NaN        NaN       NaN             NaN
# 1984           1           6.0      NaN    30000.0       NaN         30000.0
# 1985           2          44.0     21.0        NaN       NaN            21.0
# 1986           1          17.0      NaN      300.0       NaN           300.0
# 1987           1          18.0     12.0        NaN       NaN            12.0
# 1988           1           2.0      NaN    25000.0       NaN         25000.0
# 1989           1           3.0      NaN    11541.0       NaN         11541.0
# 1990           2          94.0      NaN   211000.0       NaN        211000.0
# 1991           1           NaN      NaN    30000.0       NaN         30000.0
# 1992           1           NaN      NaN      200.0       NaN           200.0
# 1993           1          55.0      NaN   670000.0       NaN        670000.0
#
#       Total damage  ('000 US$)
# 0                          NaN
# 1                     120000.0
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                       5000.0
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                      3000.0
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                      2000.0
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                      5000.0
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ...                        ...
# 1964                       NaN
# 1965                       NaN
# 1966                       NaN
# 1967                       NaN
# 1968                       NaN
# 1969                       NaN
# 1970                       NaN
# 1971                       NaN
# 1972                       NaN
# 1973                       NaN
# 1974                       NaN
# 1975                       NaN
# 1976                  350000.0
# 1977                       NaN
# 1978                    5100.0
# 1979                       NaN
# 1980                  275000.0
# 1981                       NaN
# 1982                       NaN
# 1983                       NaN
# 1984                   36000.0
# 1985                      36.0
# 1986                       NaN
# 1987                   28000.0
# 1988                       NaN
# 1989                       NaN
# 1990                       NaN
# 1991                       NaN
# 1992                       NaN
# 1993                       NaN
#
# [1994 rows x 11 columns]

# %%
disaster_years = df_emd["year"].unique()
freq = df_emd.groupby(['year','disaster type']).size()
print(freq)

for i, v in freq.items():
    print('index: ', i, 'value: ', v)
# Out:
# year  disaster type
# 1960  Earthquake               2
#       Storm                    1
# 1961  Earthquake               1
#       Flood                    1
# 1962  Flood                    1
# 1963  Earthquake               1
#       Flood                    2
# 1964  Drought                  2
#       Earthquake               1
#       Flood                    4
# 1965  Drought                  4
#       Earthquake               1
#       Epidemic                 3
#       Flood                    1
# 1966  Drought                  6
#       Earthquake               2
#       Epidemic                 2
#       Flood                    2
#       Storm                    1
# 1967  Drought                  2
#       Flood                    3
#       Landslide                1
#       Storm                    1
# 1968  Drought                  3
#       Flood                    5
#       Landslide                1
#       Storm                    1
# 1969  Drought                  6
#       Earthquake               2
#       Epidemic                 4
#                               ..
# 2014  Landslide                1
#       Storm                    5
#       Volcanic activity        1
# 2015  Drought                  9
#       Earthquake               1
#       Epidemic                10
#       Extreme temperature      2
#       Flood                   22
#       Landslide                2
#       Storm                    8
#       Wildfire                 1
# 2016  Drought                  6
#       Earthquake               2
#       Epidemic                11
#       Extreme temperature      2
#       Flood                   21
#       Landslide                2
#       Storm                    4
# 2017  Drought                  4
#       Epidemic                15
#       Extreme temperature      2
#       Flood                   19
#       Landslide                3
#       Storm                    8
#       Wildfire                 2
# 2018  Epidemic                 4
#       Extreme temperature      1
#       Flood                   15
#       Landslide                3
#       Storm                    6
# Length: 339, dtype: int64
# index:  (1960, 'Earthquake') value:  2
# index:  (1960, 'Storm') value:  1
# index:  (1961, 'Earthquake') value:  1
# index:  (1961, 'Flood') value:  1
# index:  (1962, 'Flood') value:  1
# index:  (1963, 'Earthquake') value:  1
# index:  (1963, 'Flood') value:  2
# index:  (1964, 'Drought') value:  2
# index:  (1964, 'Earthquake') value:  1
# index:  (1964, 'Flood') value:  4
# index:  (1965, 'Drought') value:  4
# index:  (1965, 'Earthquake') value:  1
# index:  (1965, 'Epidemic') value:  3
# index:  (1965, 'Flood') value:  1
# index:  (1966, 'Drought') value:  6
# index:  (1966, 'Earthquake') value:  2
# index:  (1966, 'Epidemic') value:  2
# index:  (1966, 'Flood') value:  2
# index:  (1966, 'Storm') value:  1
# index:  (1967, 'Drought') value:  2
# index:  (1967, 'Flood') value:  3
# index:  (1967, 'Landslide') value:  1
# index:  (1967, 'Storm') value:  1
# index:  (1968, 'Drought') value:  3
# index:  (1968, 'Flood') value:  5
# index:  (1968, 'Landslide') value:  1
# index:  (1968, 'Storm') value:  1
# index:  (1969, 'Drought') value:  6
# index:  (1969, 'Earthquake') value:  2
# index:  (1969, 'Epidemic') value:  4
# index:  (1969, 'Flood') value:  3
# index:  (1969, 'Storm') value:  1
# index:  (1970, 'Drought') value:  1
# index:  (1970, 'Epidemic') value:  3
# index:  (1970, 'Flood') value:  2
# index:  (1970, 'Storm') value:  1
# index:  (1971, 'Drought') value:  6
# index:  (1971, 'Epidemic') value:  1
# index:  (1971, 'Flood') value:  1
# index:  (1972, 'Drought') value:  3
# index:  (1972, 'Flood') value:  1
# index:  (1972, 'Storm') value:  2
# index:  (1973, 'Drought') value:  1
# index:  (1973, 'Flood') value:  3
# index:  (1973, 'Wildfire') value:  1
# index:  (1974, 'Drought') value:  1
# index:  (1974, 'Epidemic') value:  1
# index:  (1974, 'Flood') value:  5
# index:  (1975, 'Complex Disasters') value:  1
# index:  (1975, 'Flood') value:  5
# index:  (1975, 'Storm') value:  4
# index:  (1976, 'Drought') value:  2
# index:  (1976, 'Epidemic') value:  3
# index:  (1976, 'Flood') value:  1
# index:  (1976, 'Storm') value:  1
# index:  (1977, 'Drought') value:  6
# index:  (1977, 'Epidemic') value:  3
# index:  (1977, 'Flood') value:  8
# index:  (1977, 'Storm') value:  3
# index:  (1977, 'Volcanic activity') value:  4
# index:  (1978, 'Drought') value:  3
# index:  (1978, 'Epidemic') value:  5
# index:  (1978, 'Flood') value:  8
# index:  (1978, 'Insect infestation') value:  1
# index:  (1978, 'Storm') value:  3
# index:  (1978, 'Wildfire') value:  1
# index:  (1979, 'Drought') value:  4
# index:  (1979, 'Epidemic') value:  2
# index:  (1979, 'Flood') value:  6
# index:  (1979, 'Insect infestation') value:  1
# index:  (1979, 'Storm') value:  2
# index:  (1980, 'Drought') value:  9
# index:  (1980, 'Earthquake') value:  1
# index:  (1980, 'Epidemic') value:  5
# index:  (1980, 'Landslide') value:  1
# index:  (1980, 'Storm') value:  1
# index:  (1981, 'Drought') value:  7
# index:  (1981, 'Epidemic') value:  3
# index:  (1981, 'Flood') value:  7
# index:  (1981, 'Storm') value:  2
# index:  (1982, 'Drought') value:  8
# index:  (1982, 'Earthquake') value:  1
# index:  (1982, 'Epidemic') value:  3
# index:  (1982, 'Flood') value:  6
# index:  (1982, 'Landslide') value:  1
# index:  (1982, 'Mass movement (dry)') value:  1
# index:  (1982, 'Storm') value:  3
# index:  (1983, 'Drought') value:  17
# index:  (1983, 'Earthquake') value:  1
# index:  (1983, 'Epidemic') value:  3
# index:  (1983, 'Flood') value:  2
# index:  (1983, 'Storm') value:  4
# index:  (1984, 'Drought') value:  6
# index:  (1984, 'Epidemic') value:  5
# index:  (1984, 'Flood') value:  3
# index:  (1984, 'Storm') value:  8
# index:  (1984, 'Volcanic activity') value:  1
# index:  (1984, 'Wildfire') value:  1
# index:  (1985, 'Drought') value:  1
# index:  (1985, 'Earthquake') value:  1
# index:  (1985, 'Epidemic') value:  5
# index:  (1985, 'Flood') value:  10
# index:  (1985, 'Insect infestation') value:  2
# index:  (1985, 'Storm') value:  3
# index:  (1985, 'Wildfire') value:  1
# index:  (1986, 'Drought') value:  1
# index:  (1986, 'Epidemic') value:  4
# index:  (1986, 'Flood') value:  3
# index:  (1986, 'Insect infestation') value:  13
# index:  (1986, 'Storm') value:  1
# index:  (1986, 'Volcanic activity') value:  1
# index:  (1987, 'Drought') value:  6
# index:  (1987, 'Earthquake') value:  2
# index:  (1987, 'Epidemic') value:  10
# index:  (1987, 'Flood') value:  3
# index:  (1987, 'Insect infestation') value:  13
# index:  (1987, 'Storm') value:  4
# index:  (1988, 'Drought') value:  8
# index:  (1988, 'Earthquake') value:  3
# index:  (1988, 'Epidemic') value:  11
# index:  (1988, 'Flood') value:  15
# index:  (1988, 'Insect infestation') value:  13
# index:  (1988, 'Landslide') value:  1
# index:  (1988, 'Mass movement (dry)') value:  1
# index:  (1988, 'Storm') value:  4
# index:  (1989, 'Drought') value:  4
# index:  (1989, 'Earthquake') value:  2
# index:  (1989, 'Epidemic') value:  10
# index:  (1989, 'Flood') value:  11
# index:  (1989, 'Landslide') value:  1
# index:  (1989, 'Storm') value:  5
# index:  (1990, 'Drought') value:  6
# index:  (1990, 'Earthquake') value:  4
# index:  (1990, 'Epidemic') value:  6
# index:  (1990, 'Extreme temperature ') value:  1
# index:  (1990, 'Flood') value:  6
# index:  (1990, 'Storm') value:  1
# index:  (1991, 'Drought') value:  9
# index:  (1991, 'Epidemic') value:  15
# index:  (1991, 'Flood') value:  6
# index:  (1991, 'Mass movement (dry)') value:  1
# index:  (1991, 'Storm') value:  3
# index:  (1991, 'Volcanic activity') value:  1
# index:  (1991, 'Wildfire') value:  1
# index:  (1992, 'Complex Disasters') value:  1
# index:  (1992, 'Drought') value:  4
# index:  (1992, 'Earthquake') value:  3
# index:  (1992, 'Epidemic') value:  11
# index:  (1992, 'Extreme temperature ') value:  1
# index:  (1992, 'Flood') value:  1
# index:  (1992, 'Insect infestation') value:  1
# index:  (1993, 'Drought') value:  3
# index:  (1993, 'Earthquake') value:  1
# index:  (1993, 'Epidemic') value:  1
# index:  (1993, 'Flood') value:  8
# index:  (1993, 'Landslide') value:  1
# index:  (1993, 'Mass movement (dry)') value:  1
# index:  (1993, 'Storm') value:  4
# index:  (1994, 'Drought') value:  1
# index:  (1994, 'Earthquake') value:  2
# index:  (1994, 'Epidemic') value:  7
# index:  (1994, 'Flood') value:  17
# index:  (1994, 'Landslide') value:  1
# index:  (1994, 'Storm') value:  6
# index:  (1994, 'Wildfire') value:  1
# index:  (1995, 'Drought') value:  4
# index:  (1995, 'Earthquake') value:  1
# index:  (1995, 'Epidemic') value:  6
# index:  (1995, 'Extreme temperature ') value:  1
# index:  (1995, 'Flood') value:  15
# index:  (1995, 'Insect infestation') value:  1
# index:  (1995, 'Storm') value:  2
# index:  (1995, 'Volcanic activity') value:  1
# index:  (1995, 'Wildfire') value:  1
# index:  (1996, 'Drought') value:  4
# index:  (1996, 'Epidemic') value:  21
# index:  (1996, 'Extreme temperature ') value:  2
# index:  (1996, 'Flood') value:  13
# index:  (1996, 'Landslide') value:  1
# index:  (1996, 'Storm') value:  5
# index:  (1997, 'Drought') value:  6
# index:  (1997, 'Earthquake') value:  1
# index:  (1997, 'Epidemic') value:  21
# index:  (1997, 'Flood') value:  15
# index:  (1997, 'Insect infestation') value:  1
# index:  (1997, 'Landslide') value:  1
# index:  (1997, 'Storm') value:  3
# index:  (1997, 'Wildfire') value:  1
# index:  (1998, 'Complex Disasters') value:  1
# index:  (1998, 'Drought') value:  8
# index:  (1998, 'Epidemic') value:  22
# index:  (1998, 'Flood') value:  18
# index:  (1998, 'Insect infestation') value:  1
# index:  (1998, 'Landslide') value:  1
# index:  (1998, 'Storm') value:  1
# index:  (1998, 'Wildfire') value:  3
# index:  (1999, 'Drought') value:  8
# index:  (1999, 'Earthquake') value:  1
# index:  (1999, 'Epidemic') value:  26
# index:  (1999, 'Flood') value:  20
# index:  (1999, 'Storm') value:  7
# index:  (1999, 'Volcanic activity') value:  1
# index:  (1999, 'Wildfire') value:  1
# index:  (2000, 'Drought') value:  3
# index:  (2000, 'Earthquake') value:  1
# index:  (2000, 'Epidemic') value:  30
# index:  (2000, 'Extreme temperature ') value:  2
# index:  (2000, 'Flood') value:  20
# index:  (2000, 'Landslide') value:  3
# index:  (2000, 'Storm') value:  8
# index:  (2000, 'Wildfire') value:  2
# index:  (2001, 'Drought') value:  12
# index:  (2001, 'Earthquake') value:  1
# index:  (2001, 'Epidemic') value:  25
# index:  (2001, 'Flood') value:  25
# index:  (2001, 'Landslide') value:  3
# index:  (2001, 'Storm') value:  4
# index:  (2001, 'Volcanic activity') value:  1
# index:  (2001, 'Wildfire') value:  1
# index:  (2002, 'Drought') value:  10
# index:  (2002, 'Earthquake') value:  3
# index:  (2002, 'Epidemic') value:  23
# index:  (2002, 'Extreme temperature ') value:  1
# index:  (2002, 'Flood') value:  22
# index:  (2002, 'Landslide') value:  1
# index:  (2002, 'Storm') value:  9
# index:  (2002, 'Volcanic activity') value:  1
# index:  (2002, 'Wildfire') value:  2
# index:  (2003, 'Drought') value:  5
# index:  (2003, 'Earthquake') value:  1
# index:  (2003, 'Epidemic') value:  19
# index:  (2003, 'Extreme temperature ') value:  1
# index:  (2003, 'Flood') value:  28
# index:  (2003, 'Landslide') value:  1
# index:  (2003, 'Storm') value:  8
# index:  (2004, 'Drought') value:  5
# index:  (2004, 'Earthquake') value:  7
# index:  (2004, 'Epidemic') value:  19
# index:  (2004, 'Flood') value:  16
# index:  (2004, 'Insect infestation') value:  11
# index:  (2004, 'Storm') value:  5
# index:  (2004, 'Wildfire') value:  1
# index:  (2005, 'Drought') value:  13
# index:  (2005, 'Earthquake') value:  3
# index:  (2005, 'Epidemic') value:  27
# index:  (2005, 'Flood') value:  20
# index:  (2005, 'Storm') value:  6
# index:  (2005, 'Volcanic activity') value:  2
# index:  (2006, 'Drought') value:  3
# index:  (2006, 'Earthquake') value:  2
# index:  (2006, 'Epidemic') value:  26
# index:  (2006, 'Flood') value:  23
# index:  (2006, 'Insect infestation') value:  1
# index:  (2006, 'Landslide') value:  1
# index:  (2006, 'Storm') value:  4
# index:  (2006, 'Volcanic activity') value:  1
# index:  (2007, 'Complex Disasters') value:  1
# index:  (2007, 'Drought') value:  6
# index:  (2007, 'Epidemic') value:  18
# index:  (2007, 'Extreme temperature ') value:  1
# index:  (2007, 'Flood') value:  36
# index:  (2007, 'Landslide') value:  1
# index:  (2007, 'Storm') value:  7
# index:  (2007, 'Volcanic activity') value:  1
# index:  (2007, 'Wildfire') value:  3
# index:  (2008, 'Drought') value:  9
# index:  (2008, 'Earthquake') value:  2
# index:  (2008, 'Epidemic') value:  24
# index:  (2008, 'Flood') value:  33
# index:  (2008, 'Landslide') value:  1
# index:  (2008, 'Mass movement (dry)') value:  1
# index:  (2008, 'Storm') value:  7
# index:  (2008, 'Wildfire') value:  2
# index:  (2009, 'Drought') value:  5
# index:  (2009, 'Earthquake') value:  1
# index:  (2009, 'Epidemic') value:  18
# index:  (2009, 'Flood') value:  32
# index:  (2009, 'Insect infestation') value:  1
# index:  (2009, 'Landslide') value:  1
# index:  (2009, 'Storm') value:  9
# index:  (2009, 'Wildfire') value:  1
# index:  (2010, 'Drought') value:  6
# index:  (2010, 'Epidemic') value:  16
# index:  (2010, 'Flood') value:  33
# index:  (2010, 'Insect infestation') value:  1
# index:  (2010, 'Landslide') value:  6
# index:  (2010, 'Storm') value:  5
# index:  (2010, 'Wildfire') value:  1
# index:  (2011, 'Drought') value:  11
# index:  (2011, 'Epidemic') value:  12
# index:  (2011, 'Flood') value:  27
# index:  (2011, 'Storm') value:  8
# index:  (2012, 'Complex Disasters') value:  1
# index:  (2012, 'Drought') value:  8
# index:  (2012, 'Epidemic') value:  11
# index:  (2012, 'Extreme temperature ') value:  1
# index:  (2012, 'Flood') value:  22
# index:  (2012, 'Landslide') value:  1
# index:  (2012, 'Storm') value:  6
# index:  (2013, 'Drought') value:  2
# index:  (2013, 'Epidemic') value:  12
# index:  (2013, 'Flood') value:  27
# index:  (2013, 'Storm') value:  5
# index:  (2013, 'Wildfire') value:  2
# index:  (2014, 'Animal accident') value:  1
# index:  (2014, 'Drought') value:  5
# index:  (2014, 'Earthquake') value:  3
# index:  (2014, 'Epidemic') value:  14
# index:  (2014, 'Flood') value:  16
# index:  (2014, 'Landslide') value:  1
# index:  (2014, 'Storm') value:  5
# index:  (2014, 'Volcanic activity') value:  1
# index:  (2015, 'Drought') value:  9
# index:  (2015, 'Earthquake') value:  1
# index:  (2015, 'Epidemic') value:  10
# index:  (2015, 'Extreme temperature ') value:  2
# index:  (2015, 'Flood') value:  22
# index:  (2015, 'Landslide') value:  2
# index:  (2015, 'Storm') value:  8
# index:  (2015, 'Wildfire') value:  1
# index:  (2016, 'Drought') value:  6
# index:  (2016, 'Earthquake') value:  2
# index:  (2016, 'Epidemic') value:  11
# index:  (2016, 'Extreme temperature ') value:  2
# index:  (2016, 'Flood') value:  21
# index:  (2016, 'Landslide') value:  2
# index:  (2016, 'Storm') value:  4
# index:  (2017, 'Drought') value:  4
# index:  (2017, 'Epidemic') value:  15
# index:  (2017, 'Extreme temperature ') value:  2
# index:  (2017, 'Flood') value:  19
# index:  (2017, 'Landslide') value:  3
# index:  (2017, 'Storm') value:  8
# index:  (2017, 'Wildfire') value:  2
# index:  (2018, 'Epidemic') value:  4
# index:  (2018, 'Extreme temperature ') value:  1
# index:  (2018, 'Flood') value:  15
# index:  (2018, 'Landslide') value:  3
# index:  (2018, 'Storm') value:  6

# %%
#jaar bewerken
x =df_emd['year'].value_counts()

for i,g in x.iteritems()
    print(g),
#h = pd.Series(np.concatenate((series.values, [6])))
#h = pd.Series()
#for i in range(len(x))
#h = x.set_value(i, i**2)
#df['Column'].values[i] = something/update/new_value\n",
#mylist, df['Column'] = []

#for <condition>:
#mylist.append(something/update/new_value)
#df['Column'] = mylist"

# %%
all_indicators = df_sdg["Indicator Name"].unique()
all_codes = df_sdg["Indicator Code"].unique()
type(all_codes)

dfc = pd.read_csv("other/countriescodes.txt", sep = ",", encoding = 'latin-1')
l = dfc[dfc['sub-region'] == "Sub-Saharan Africa"]["alpha-3"]
WDI = pd.read_csv("WDI/WDIData.csv")
WDI_SSA = WDI[WDI["Country_Code"].isin(l)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country_Code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-84a2e978e186> in <module>()
#       6 l = dfc[dfc['sub-region'] == "Sub-Saharan Africa"]["alpha-3"]
#       7 WDI = pd.read_csv("WDI/WDIData.csv")
# ----> 8 WDI_SSA = WDI[WDI["Country_Code"].isin(l)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country_Code'
