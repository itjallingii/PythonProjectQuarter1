# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os


plt.style.use('ggplot')

# %%
os.chdir('/Users/Martijn/Documents/Rdownloads')
os.getcwd()
# Out:
# '/Users/Martijn/Documents/Rdownloads'

# %%
#country names un Sub-Saharan Africa
#'Sub-Saharan Africa',
 #'Sub-Saharan Africa (excluding high income)',
 #'Sub-Saharan Africa (IDA & IBRD countries)'
#SN.ITK.DEFC.ZS <- indicator code undernourishment

# %%
df_wdi = pd.read_csv("WDIData.csv")
#We only want the indicator with the % of undernourishment
df_wdi = df_wdi[df_wdi["Indicator Code"] == 'SN.ITK.DEFC.ZS']
# Set the years from colums to rows
df_wdi = pd.melt(df_wdi,id_vars =["Country Name","Country Code","Indicator Name","Indicator Code"],
          var_name = "Years", value_name = "perc. undernourishment")
# Sort the values first by Country Name and than by Years
df_wdi = df_wdi.sort_values(["Country Name", "Years"])

# %%
#create plot of undernourishment
x = df_wdi[df_wdi["Country Name"] == 'World']["Years"]
y1 = df_wdi[df_wdi["Country Name"] == 'World']["perc. undernourishment"]
y2 = df_wdi[df_wdi["Country Name"] == 'Sub-Saharan Africa']["perc. undernourishment"]
y3 = df_wdi[df_wdi["Country Name"] == 'Central Europe and the Baltics']["perc. undernourishment"]
y4 = df_wdi[df_wdi["Country Name"] == 'East Asia & Pacific']["perc. undernourishment"]

plt.plot(x,y1, color = "Blue",label = "World")
plt.plot(x,y2, color = "Red",label = "Sub-Saharan Africa")
plt.plot(x,y3, color = "Green",label = "Central Europe and the Baltics")
plt.plot(x,y4, color = "Yellow",label = "East Asia & Pacific")
plt.xlabel("Years")
plt.ylabel("% of undernourishment")

plt.legend(loc=((1.05,0.72)))
plt.show()

# %%
#create right dataset for Cereal Yield
df_wdi2 = pd.read_csv("WDIData.csv")
#We only want the indicator with Cereal Yield
df_wdi2 = df_wdi2[df_wdi2["Indicator Code"] == 'AG.YLD.CREL.KG']
# Set the years from colums to rows
df_wdi2 = pd.melt(df_wdi2,id_vars =["Country Name","Country Code","Indicator Name","Indicator Code"],
              var_name = "Years", value_name = "Cereal Yield (kg per Hectare)")
# Sort the values first by Country Name and than by Years
df_wdi2 = df_wdi2.sort_values(["Country Name","Years"])
df_wdi2
# Out:
#       Country Name Country Code                 Indicator Name  \
# 47     Afghanistan          AFG  Cereal yield (kg per hectare)
# 311    Afghanistan          AFG  Cereal yield (kg per hectare)
# 575    Afghanistan          AFG  Cereal yield (kg per hectare)
# 839    Afghanistan          AFG  Cereal yield (kg per hectare)
# 1103   Afghanistan          AFG  Cereal yield (kg per hectare)
# 1367   Afghanistan          AFG  Cereal yield (kg per hectare)
# 1631   Afghanistan          AFG  Cereal yield (kg per hectare)
# 1895   Afghanistan          AFG  Cereal yield (kg per hectare)
# 2159   Afghanistan          AFG  Cereal yield (kg per hectare)
# 2423   Afghanistan          AFG  Cereal yield (kg per hectare)
# 2687   Afghanistan          AFG  Cereal yield (kg per hectare)
# 2951   Afghanistan          AFG  Cereal yield (kg per hectare)
# 3215   Afghanistan          AFG  Cereal yield (kg per hectare)
# 3479   Afghanistan          AFG  Cereal yield (kg per hectare)
# 3743   Afghanistan          AFG  Cereal yield (kg per hectare)
# 4007   Afghanistan          AFG  Cereal yield (kg per hectare)
# 4271   Afghanistan          AFG  Cereal yield (kg per hectare)
# 4535   Afghanistan          AFG  Cereal yield (kg per hectare)
# 4799   Afghanistan          AFG  Cereal yield (kg per hectare)
# 5063   Afghanistan          AFG  Cereal yield (kg per hectare)
# 5327   Afghanistan          AFG  Cereal yield (kg per hectare)
# 5591   Afghanistan          AFG  Cereal yield (kg per hectare)
# 5855   Afghanistan          AFG  Cereal yield (kg per hectare)
# 6119   Afghanistan          AFG  Cereal yield (kg per hectare)
# 6383   Afghanistan          AFG  Cereal yield (kg per hectare)
# 6647   Afghanistan          AFG  Cereal yield (kg per hectare)
# 6911   Afghanistan          AFG  Cereal yield (kg per hectare)
# 7175   Afghanistan          AFG  Cereal yield (kg per hectare)
# 7439   Afghanistan          AFG  Cereal yield (kg per hectare)
# 7703   Afghanistan          AFG  Cereal yield (kg per hectare)
# ...            ...          ...                            ...
# 7919      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 8183      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 8447      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 8711      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 8975      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 9239      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 9503      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 9767      Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 10031     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 10295     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 10559     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 10823     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 11087     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 11351     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 11615     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 11879     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 12143     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 12407     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 12671     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 12935     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 13199     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 13463     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 13727     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 13991     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 14255     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 14519     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 14783     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 15047     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 15311     Zimbabwe          ZWE  Cereal yield (kg per hectare)
# 15575     Zimbabwe          ZWE  Cereal yield (kg per hectare)
#
#        Indicator Code        Years  Cereal Yield (kg per Hectare)
# 47     AG.YLD.CREL.KG         1960                            NaN
# 311    AG.YLD.CREL.KG         1961                         1115.1
# 575    AG.YLD.CREL.KG         1962                         1079.0
# 839    AG.YLD.CREL.KG         1963                          985.8
# 1103   AG.YLD.CREL.KG         1964                         1082.8
# 1367   AG.YLD.CREL.KG         1965                         1098.9
# 1631   AG.YLD.CREL.KG         1966                         1012.3
# 1895   AG.YLD.CREL.KG         1967                         1224.5
# 2159   AG.YLD.CREL.KG         1968                         1287.5
# 2423   AG.YLD.CREL.KG         1969                         1310.4
# 2687   AG.YLD.CREL.KG         1970                         1105.1
# 2951   AG.YLD.CREL.KG         1971                          976.2
# 3215   AG.YLD.CREL.KG         1972                         1006.9
# 3479   AG.YLD.CREL.KG         1973                         1279.6
# 3743   AG.YLD.CREL.KG         1974                         1301.9
# 4007   AG.YLD.CREL.KG         1975                         1316.4
# 4271   AG.YLD.CREL.KG         1976                         1362.4
# 4535   AG.YLD.CREL.KG         1977                         1224.0
# 4799   AG.YLD.CREL.KG         1978                         1291.9
# 5063   AG.YLD.CREL.KG         1979                         1323.7
# 5327   AG.YLD.CREL.KG         1980                         1349.0
# 5591   AG.YLD.CREL.KG         1981                         1338.3
# 5855   AG.YLD.CREL.KG         1982                         1330.2
# 6119   AG.YLD.CREL.KG         1983                         1355.6
# 6383   AG.YLD.CREL.KG         1984                         1334.1
# 6647   AG.YLD.CREL.KG         1985                         1331.7
# 6911   AG.YLD.CREL.KG         1986                         1314.0
# 7175   AG.YLD.CREL.KG         1987                         1359.8
# 7439   AG.YLD.CREL.KG         1988                         1285.7
# 7703   AG.YLD.CREL.KG         1989                         1237.6
# ...               ...          ...                            ...
# 7919   AG.YLD.CREL.KG         1989                         1509.6
# 8183   AG.YLD.CREL.KG         1990                         1625.4
# 8447   AG.YLD.CREL.KG         1991                         1336.0
# 8711   AG.YLD.CREL.KG         1992                          412.1
# 8975   AG.YLD.CREL.KG         1993                         1502.0
# 9239   AG.YLD.CREL.KG         1994                         1134.6
# 9503   AG.YLD.CREL.KG         1995                          548.2
# 9767   AG.YLD.CREL.KG         1996                         1258.7
# 10031  AG.YLD.CREL.KG         1997                         1054.3
# 10295  AG.YLD.CREL.KG         1998                         1016.6
# 10559  AG.YLD.CREL.KG         1999                         1069.0
# 10823  AG.YLD.CREL.KG         2000                         1159.6
# 11087  AG.YLD.CREL.KG         2001                         1194.0
# 11351  AG.YLD.CREL.KG         2002                          539.2
# 11615  AG.YLD.CREL.KG         2003                          795.4
# 11879  AG.YLD.CREL.KG         2004                         1206.0
# 12143  AG.YLD.CREL.KG         2005                          653.8
# 12407  AG.YLD.CREL.KG         2006                          934.3
# 12671  AG.YLD.CREL.KG         2007                          806.8
# 12935  AG.YLD.CREL.KG         2008                          309.7
# 13199  AG.YLD.CREL.KG         2009                          452.3
# 13463  AG.YLD.CREL.KG         2010                          733.7
# 13727  AG.YLD.CREL.KG         2011                          587.6
# 13991  AG.YLD.CREL.KG         2012                          696.0
# 14255  AG.YLD.CREL.KG         2013                          669.7
# 14519  AG.YLD.CREL.KG         2014                          836.3
# 14783  AG.YLD.CREL.KG         2015                          558.6
# 15047  AG.YLD.CREL.KG         2016                          580.0
# 15311  AG.YLD.CREL.KG         2017                            NaN
# 15575  AG.YLD.CREL.KG  Unnamed: 62                            NaN
#
# [15576 rows x 6 columns]

# %%
x = df_wdi2[df_wdi2["Country Name"] == 'World']["Years"]
y1 = df_wdi2[df_wdi2["Country Name"] == 'World']["Cereal Yield (kg per Hectare)"]
y2 = df_wdi2[df_wdi2["Country Name"] == 'Sub-Saharan Africa']["Cereal Yield (kg per Hectare)"]
y3 = df_wdi2[df_wdi2["Country Name"] == 'Central Europe and the Baltics']["Cereal Yield (kg per Hectare)"]
y4 = df_wdi2[df_wdi2["Country Name"] == 'East Asia & Pacific']["Cereal Yield (kg per Hectare)"]

plt.plot(x,y1, color = "Blue",label = "World")
plt.plot(x,y2, color = "Red",label = "Sub-Saharan Africa")
plt.plot(x,y3, color = "Green",label = "Central Europe and the Baltics")
plt.plot(x,y4, color = "Yellow",label = "East Asia & Pacific")
plt.xlabel("Years")
plt.ylabel("Cereal Yield (kg per Hectare)")

plt.legend(loc=((1.05,0.72)))
plt.show()
